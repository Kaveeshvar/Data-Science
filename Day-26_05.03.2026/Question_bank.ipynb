# %% [markdown]
# ## SECTION 1: Rapid Python Syntax Questions (15)

# %% [markdown]
# 1) What is the difference between list and tuple?
#
# Answer:
# List is mutable (can change), tuple is immutable (cannot change).
# Example:

# %%
l = [1,2,3]
l[0] = 10  # allowed

t = (1,2,3)
# t[0] = 10  # error

# %% [markdown]
# Trap: Why use tuple? → Faster, safe from accidental modification.

# %% [markdown]
# 2) What does *args and **kwargs mean?
#
# Answer:
# *args collects positional arguments as a tuple.
# **kwargs collects keyword arguments as a dictionary.
#
# 3) What is list comprehension?
#
# Answer:

# %%
squares = [x*x for x in range(5)]

# %% [markdown]
# Short way to create lists.
#
# 4) Difference between is and ==?
#
# Answer:
# == checks value equality.
# is checks memory reference.
#
# 5) What is Python’s default data type for numbers?
#
# Answer: int (for whole numbers).
#
# 6) What is indentation in Python?
#
# Answer:
# Indentation defines code blocks (instead of {}).
#
# 7) What does enumerate() do?
#
# Answer:
# Returns index + value while looping.
#
# 8) How to reverse a string?

# %%
s[::-1]

# %% [markdown]
# 9) What is lambda?
#
# Answer:
# Anonymous small function.
#
# 10) Difference between append() and extend()?
#
# append() adds single element.
# extend() adds multiple elements.
#
# 11) What is __init__?
#
# Constructor method in class.
#
# 12) What does pass do?
#
# Placeholder; does nothing.
#
# 13) What is None?
#
# Represents absence of value.
#
# 14) What is exception handling?
#
# Using try-except to prevent crashes.
#
# 15) What is recursion?
#
# Function calling itself.

# %% [markdown]
# ## SECTION 2: Live Coding Questions (10)
#
# 1) Reverse a string

# %%
def reverse_string(s):
    return s[::-1]

# %% [markdown]
# Time: O(n)
# Space: O(n)
# Common mistake: modifying original string.
#
# 2) Check palindrome

# %%
def is_palindrome(s):
    return s == s[::-1]

# %% [markdown]
# O(n)
#
# 3) Find second largest in list

# %%
def second_largest(nums):
    first = second = float('-inf')
    for n in nums:
        if n > first:
            second = first
            first = n
        elif first > n > second:
            second = n
    return second

# %% [markdown]
# Time: O(n)
# Mistake: sorting (O(n log n)) unnecessarily.
#
# 4) Fibonacci using recursion

# %%
def fib(n):
    if n <= 1:
        return n
    return fib(n-1) + fib(n-2)

# %% [markdown]
# Time: O(2^n)
# Trap: ask for optimized version (DP).
#
# 5) Binary Search

# %%
def binary_search(arr, target):
    l, r = 0, len(arr)-1
    while l <= r:
        mid = (l+r)//2
        if arr[mid] == target:
            return mid
        elif arr[mid] < target:
            l = mid+1
        else:
            r = mid-1
    return -1

# %% [markdown]
# O(log n)
#
# 6) Count frequency of characters

# %%
from collections import Counter
Counter(s)
